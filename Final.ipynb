# %% [markdown]
# # Final Project
# # Mammalian Paleontology Database & Object-oriented Program
# ### By Caden Bokarae

# %% [markdown]
# # Inputs
#  While this code is relatively long it represents a rather simple Object-oriented Program similar to what we performed together in class simply at a larger scale.
#
#  This codes inputs include the main class which in this case is the variable MammalFossil:, This is followed by the def __init__ command which defines the constructor method of the class MammalFossil and with the command self. allows for an object to be created holding as much information as you want. Finally for the code to respond back with the desired information i used the Display_info input along with the print command. Finnaly for the two plots made using this information include listing out each fossil name and then listing out each first and last apperance in order, then by using matplotlib creating plots was simple.

# %% [markdown]
# # Outputs
# The Idea of this code is to output relevant information about any of the 40 fossils listed in the database this includes, name of the genus, first apperance in the fossil record, final apperance in the fossil record, the order, family, where it evolved and finnaly a short description of the mammal. Along with the OOP using this information i also created two plots one of the last apperance of each fossil to try and observe any extinction events and finnaly a plot showing the first and last apperance of each fossil connected by a line to try and see which mammals present in this code coexisted.

# %%
class MammalFossil:
    def __init__(self, name, first_appearance, last_appearance, order, family, evolved, description):
        self.name = name
        self.first_appearance = first_appearance
        self.last_appearance = last_appearance
        self.order = order
        self.family = family
        self.evolved = evolved
        self.description = description

    def display_info(self):
        print("Name:", self.name)
        print("First Appearance:", self.first_appearance, "million years ago")
        print("Last Appearance:", self.last_appearance, "million years ago")
        print("Order:", self.order)
        print("Family:", self.family)
        print("Evolved:", self.evolved)
        print("Description:", self.description)


fossils = {
    "Morganucodon": MammalFossil("Morganucodon", 200, 165, "Morganucodonta", "Cynodontia", "Laurasia",
                                 "Small shrew like mammal, some of the first mammals to have deciduous teeth. Upper and lower molars did not occlude."),
    "Castorocauda": MammalFossil("Castorocauda", 165, 100, "Docodonta", "Cynodontia", "Laurasia (Mongolia)",
                                 "Semi aquatic and beaver like with a large flat paddle like tail. Largest known Jurassic mammaliaform."),
    "Docofossor": MammalFossil("Docofossor", 170, 160, "Docodonta", "Mammaliaformes", "Laurasia (China)",
                               "A burrowing mammal filling a similar niche to modern day moles."),
    "Maelestes": MammalFossil("Maelestes", 75, 71, "Cimolesta", "Cimolestidae", "China",
                              "Shrew like mammal although it was a eutherian it was not a placental mammal. Presence of epipubic bone places it in a family similar to modern day marsupials."),
    "Alcidedorbignya": MammalFossil("Alcidedorbignya", 66, 61, "Pantodonta", "Inopinata", "South America",
                                    "Squirrel like, one of the most primitive pantodonts and only genus found in South America."),
    "Ptilodus": MammalFossil("Ptilodus", 66, 56, "Multituberculata", "Cimolodonta", "North America",
                             "Large climbing mammal at around 20 inches long. Long tail used for climbing and large diastema present."),
    "Chriacus": MammalFossil("Chriacus", 66, 56, "Condylarth", "Arctocyonidae", "North America",
                             "Placental omnivore physically similar to a kinkajou. Around 3 feet long and able to rotate ankles to allow climbing downwards like modern day squirrels."),
    "Uintatherium": MammalFossil("Uintatherium", 56, 38, "Dinocerata", "Uintatheriidae", "North America",
                                 "Large browsing herbivore around 13 feet long similar to modern day rhinos or hippopotamus. Had large knob like ossicones across its skull which protruded 2–10 inches."),
    "Champsosaurus": MammalFossil("Champsosaurus", 93, 55, "Choristodera", "Neochoristodera", "Asia",
                                  "Crocodilian like, expanded temporal arches for more powerful jaw muscles."),
    "Hyracotherium": MammalFossil("Hyracotherium", 55, 45, "Perissodactyla", "Paleotheriidae", "Laurasia (North America)",
                                  "Horse like animal around the size of a modern day cat."),
    "Oxyaena": MammalFossil("Oxyaena", 56, 50, "Oxyaenodonta", "Ferae", "North and Central America",
                            "Wolverine like predator around 3.5 feet long. Distinctive loss of upper and lower third molar."),
    "Tytthaena": MammalFossil("Tytthaena", 59, 55, "Oxyaenodonta", "Ferae", "North America",
                              "Relative of Oxyaena, smallest oxyaenid known, distinguished by narrow molars and elongated talonids."),
    "Hyaenodontidae": MammalFossil("Hyaenodontidae", 55, 17, "Hyaenodonta", "Ferae", "Europe (Diversified in Africa)",
                                   "Largest African predator of its time with Simbakubwa weighing over 1500 kilograms."),
    "Eomanis": MammalFossil("Eomanis", 48, 46, "Pholidota", "Eupholidota", "Europe",
                            "First instance of an armored pangolin in fossil record, small insect eater."),
    "Onychonycteris": MammalFossil("Onychonycteris", 52.5, 52, "Chiroptera", "Onychonycteridae", "North America",
                                   "Unique wing structure, lack of echolocation and presence of claws on all five fingers place this as one of the most primitive bats found in the fossil record."),
    "Moropus": MammalFossil("Moropus", 20.43, 13.6, "Perissodactyla", "Chalicotheriidae", "North America",
                            "Large herbivore around 8 feet tall, similar characteristics to a giant tapir. Large diastema separating the incisors."),
    "Nuralagus": MammalFossil("Nuralagus", 5.4, 2.4, "Lagomorpha", "Leporidae", "Menorca (Spanish island)",
                              "Largest lagomorph (families including rabbits and pika) to have ever existed at around 26 pounds in a case of island gigantism."),
    "Diacodexis": MammalFossil("Diacodexis", 55, 46, "Artiodactyla", "Diacodexeidae", "North America and Europe",
                               "Oldest known even toed ungulate would resemble a small 1.5 foot deer."),
    "Rodhocetus": MammalFossil("Rodhocetus", 47, 46, "Artiodactyla", "Whippomorpha", "Modern day Pakistan",
                               "Represents a transitional species of whale between a small land dwelling mammal and what we see today in Cetacea. Around 6 to 9 feet long."),
    "Maotherium": MammalFossil("Maotherium", 124.6, 124, "Symmetrodonta", "Zhangheotheriidae", "China",
                               "Small and rodent like burrower. Considered a transitional species in the evolution of the middle ear with Meckel’s cartilage still present in adulthood."),
    "Arsinoitherium": MammalFossil("Arsinoitherium", 36, 27, "Embrithopoda", "Arsinoitheriidae", "Africa",
                                   "Similar to a large two horned rhinoceros. Physiology did not allow them to run."),
   "Purgatorius": MammalFossil("Purgatorius", 66, 63, "Plesiadapiformes", "Purgatoriidae", "North America",
                                "Earliest recorded primate in the fossil record, looked vaguely shrew like with long tail. Was an arboreal species and can be characterized as a primate due to dentition."),
    "Megacerops": MammalFossil("Megacerops", 38, 34, "Perissodactyla", "Brontorheriidae", "North America",
                               "Rhinoceros like browser genetically related to horses. Had a large pair of blunt horns and stood at over 8 feet tall."),
    "Steropodon": MammalFossil("Steropodon", 100, 96.6, "Monotremata", "Steropodontidae", "Australia",
                               "One of the oldest monotremes discovered, a genus of prehistoric platypus unique for its time due to its tribosphenic molar."),
    "Maotherium": MammalFossil("Maotherium", 124.6, 124, "Symmetrodonta", "Zhangheotheriidae", "China",
                               "Name translates to 'Fur Beast' was small and rodent like and was likely a burrower. Maotherium is considered a transitional species in the evolution of the middle ear with its Meckels cartilage still present in its adulthood."),
    "Paramylodon": MammalFossil("Paramylodon", 4.9, 0.012, "Pilosa", "Mylodontidae", "North America",
                                "Extinct species of ground sloth that went extinct around 12000 years ago. Likely went extinct due to climate change and hunting by humans. Was nearly 10 feet tall."),
    "Pumoides": MammalFossil("Pumoides", 3.0, 2.5, "Feliformia", "Felidae", "South America",
                             "Extinct cat within the Puma genus. Identified in Argentina through a maxilla, mandible and vertebrae."),
    "Issiodorensis": MammalFossil("Issiodorensis", 3.5, 1, "Feliformia", "Felidae", "Europe (May have originated in Africa)",
                                  "Extinct species of lynx that inhabited central Europe during the last glacial period. Considered the ancestor to all four species of living lynx today. Had short robust limbs and larger head and neck than the modern day lynx."),
    "Pachycrocuta": MammalFossil("Pachycrocuta", 5.33, 0.5, "Feliformia", "Hyaenidae", "Africa",
                                 "Known as the Giant short faced hyena Pachycrocuta is the largest species of hyaena to ever live at around 40 inches tall at the shoulder and weighing on average 250 pounds. Went extinct in Europe around 800 thousand years ago however it survived in east asia until around 500 thousand years ago."),
    "Glyptodon": MammalFossil("Glyptodon", 3.2, 0.01, "Cingulata", "Chlamyphoridae", "South America",
                              "Glyptodon reached over 2 meters long and nearly 900 pounds in weight making them one of the largest armadillos to ever live. Went extinct during the last Pleistocene extinction event due to hunting by humans and changing climate."),
    "Nimbadon": MammalFossil("Nimbadon", 25, 12, "Diprotodontia", "Diprotodontoidea", "Australia",
                             "Koala like marsupial native to northern Queensland Australia. Likely fed mainly on stems and leaves with large claws used for grasping."),
    "Diprotodon": MammalFossil("Diprotodon", 1.77, 0.04, "Diprotodontia", "Diprotodontidae", "Australia",
                               "Large quadrupedal marsupial native to Australia was around 13 feet from head to tail and weighed as much as 8000 pounds. Powerful bilophodont teeth were used to eat woody plants in bulk. Went extinct likely due to drought conditions and conflict with aboriginal Australians."),
    "Procoptodon": MammalFossil("Procoptodon", 1, 0.04, "Diprotodontia", "Macropodidae", "Australia",
                                "Largest member of Macropodidae to ever exist which includes kangaroos and wallabies and stood nearly nine feet tall. Unlike modern day kangaroos Procoptodon was unable to hop due to its weight."),
    "Eotheroides": MammalFossil("Eotheroides", 48.6, 33.9, "Sirenia", "Dugongidae", "Near Africa and Asia",
                                "An extinct species of sea cow Eotheroides had teeth that were less specialized towards consuming sea grass and algae suggesting it may have been a transition species in the family of dugongidae."),
    "Moeritherium": MammalFossil("Moeritherium", 37, 35, "Proboscidea", "Moeritheriidae", "Africa",
                                 "A strange member of proboscidea likely ancestral to modern day elephants and extinct mastodons. Had two sets of tusks and a small tapir like proboscis as an evolutionary precursor to trunks we see today on elephants. Stood only 2 and a half feet high yet had a body length of over 7 feet long."),
    "Leptictidium": MammalFossil("Leptictidium", 50, 35, "Leptictida", "Psedorhyncocyonidae", "Europe",
                                 "Similar looking to today's bandicoots however Leptictidium was most likely bipedal with powerful hind legs and a long tail. Could reach up to 35 inches in length due to its tail. Perfectly preserved specimens of this species have been found in the Messel pit of Germany."),
    "Alcidedorbignya": MammalFossil("Alcidedorbignya", 66, 61.7, "Pantodonta", "Inopinata", "South America",
                                    "Alcidedorbignya is one of the oldest pantodonts in the fossil record. V shaped ectolophs on its molars confirm this species is in fact an early pantodont."),
    "Kopidodon": MammalFossil("Kopidodon", 47, 47, "Cimolesta", "Paroxyclaenidae", "Europe",
                              "Tree dwelling squirrel like mammal, one of the largest tree dwelling mammals from the Eocene with a distinctive long bushy tail. Was able to reverse its ankles like modern day squirrels allowing them to climb down trees headfirst."),
    "Castoroides": MammalFossil("Castoroides", 1.9, 0.01, "Rodentia", "Castroridae", "North America",
                               "Much larger than modern day beavers Castoroides was over 7 feet long making it the largest rodent in North America during the Pleistocene. Castoroides had several adaptations to life underwater not seen in modern beavers due to its large lung capacity."),
    "Trigodon": MammalFossil("Trigodon", 11.6, 4, "Notoungulata", "Toxodontidae", "South America",
                             "Superficially resembled a modern day rhino but was not genetically linked to them. It had a single small horn on its forehead and was similar in size to the other megafauna of South America at the time."),
    "Jeholodens": MammalFossil("Jeholodens", 140, 120, "Eutriconodonta", "Jeholodentidae", "Asia",
                               "A long tailed possum like mammal, Jeholodens had prehensile fingers and toes and is assumed to be an insectivore. The presence of very large eyes suggests Jeholodens was a nocturnal predator."),
}



name = input("Enter Name of Fossil: ")

fossil = fossils.get(name)
if fossil:
    fossil.display_info()
else:
    print("Fossil was not found.")
# Out:
# Enter Name of Fossil:  Jeholodens
# Name: Jeholodens
# First Appearance: 140 million years ago
# Last Appearance: 120 million years ago
# Order: Eutriconodonta
# Family: Jeholodentidae
# Evolved: Asia
# Description: A long tailed possum like mammal, Jeholodens had prehensile fingers and toes and is assumed to be an insectivore. The presence of very large eyes suggests Jeholodens was a nocturnal predator.

# %% [markdown]
# # Last apperance Plot

# %%
import matplotlib.pyplot as plt

fossil_names = [
    "Morganucodon", "Castorocauda", "Docofossor", "Maelestes", "Alcidedorbignya",
    "Ptilodus", "Chriacus", "Uintatherium", "Champsosaurus", "Hyracotherium",
    "Oxyaena", "Tytthaena", "Hyaenodontidae", "Eomanis", "Onychonycteris",
    "Moropus", "Nuralagus", "Diacodexis", "Rodhocetus", "Arsinoitherium", 
    "Purgatorius", "Megacerops", "Steropodon", "Maotherium", "Paramylodon", 
    "Pumoides", "Issiodorensis", "Pachycrocuta", "Glyptodon", "Nimbadon", 
    "Diprotodon", "Procoptodon", "Eotheroides", "Moeritherium", "Leptictidium",
    "Kopidodon", "Castoroides", "Trigodon", "Jeholodens"
]

appearance_years = [
    165, 100, 160, 71, 61.7, 56, 56, 38, 55, 45, 50, 55, 17, 46, 52, 13.6, 2.4, 46, 46, 27, 63, 34, 96.6, 124, 0.012,
    2.5, 1, 0.5, 0.01, 12, 0.04, 0.04, 33.9, 35, 47, 47, 0.01, 4, 120
]

plt.figure(figsize=(12, 10))  
plt.scatter(appearance_years, fossil_names, color='darkgreen')
plt.xlabel('Last Appearance in Fossil Record (Millions of Years)')
plt.ylabel('Mammal Fossil')
plt.grid(True)
plt.show()

# %% [markdown]
# # Fossil Timeline Plot

# %%
import matplotlib.pyplot as plt

fossil_names = [
    "Morganucodon", "Castorocauda", "Docofossor", "Maelestes", "Alcidedorbignya", "Ptilodus", "Chriacus", "Uintatherium",
    "Champsosaurus", "Hyracotherium", "Oxyaena", "Tytthaena", "Hyaenodontidae", "Eomanis", "Onychonycteris", "Moropus",
    "Nuralagus", "Diacodexis", "Rodhocetus", "Arsinoitherium", "Purgatorius", "Megacerops", "Steropodon", "Maotherium",
    "Paramylodon", "Pumoides", "Issiodorensis", "Pachycrocuta", "Glyptodon", "Nimbadon", "Diprotodon", "Procoptodon",
    "Eotheroides", "Moeritherium", "Leptictidium", "Kopidodon", "Castoroides", "Trigodon", "Jeholodens"
]

first_appearance_years = [
    200, 165, 170, 75, 66, 66, 66, 56, 93, 55, 56, 59, 55, 48, 52.5, 20.43, 5.4, 55, 47, 36, 66, 38, 100, 124.6, 4.9,
    3.0, 3.5, 5.33, 3.2, 25, 1.77, 1, 48.6, 37, 50, 47, 1.9, 11.6, 140
]


last_appearance_years = [
    165, 100, 160, 71, 61.7, 56, 56, 38, 55, 45, 50, 55, 17, 46, 52, 13.6, 2.4, 46, 46, 27, 63, 34, 96.6, 124, 0.012,
    2.5, 1, 0.5, 0.01, 12, 0.04, 0.04, 33.9, 35, 47, 47, 0.01, 4, 120
]

plt.figure(figsize=(12, 10))

plt.scatter(first_appearance_years, fossil_names, color='blue', label='First Appearance')
plt.scatter(last_appearance_years, fossil_names, color='darkgreen', label='Last Appearance')

plt.hlines(fossil_names, xmin=last_appearance_years, xmax=first_appearance_years, colors='black', linewidth=2)

plt.xlabel('Time (Millions of Years Ago)')
plt.ylabel('Fossil Species')
plt.title('Fossil Timeline: First and Last Appearances')
plt.grid(True)
plt.legend()
plt.show()
